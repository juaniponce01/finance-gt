# %%
import yfinance as yf

# %%
apple_stock = yf.Ticker("AAPL")
apple_stock.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.',
#  'fullTimeEmployees': 164000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Timothy D. Cook',
#    'age': 63,
#    'title': 'CEO & Director',
#    'yearBorn': 1961,
#    'fiscalYear': 2023,
#    'totalPay': 16239562,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jeffrey E. Williams',
#    'age': 60,
#    'title': 'Chief Operating Officer',
#    'yearBorn': 1964,
#    'fiscalYear': 2023,
#    'totalPay': 4637585,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Katherine L. Adams',
#    'age': 60,
#    'title': 'Senior VP, General Counsel & Secretary',
#    'yearBorn': 1964,
#    'fiscalYear': 2023,
#    'totalPay': 4618064,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': "Ms. Deirdre  O'Brien",
#    'age': 57,
#    'title': 'Chief People Officer & Senior VP of Retail',
#    'yearBorn': 1967,
#    'fiscalYear': 2023,
#    'totalPay': 4613369,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Kevan  Parekh',
#    'age': 52,
#    'title': 'Senior VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Chris  Kondo',
#    'title': 'Senior Director of Corporate Accounting',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Suhasini  Chandramouli',
#    'title': 'Director of Investor Relations',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Greg  Joswiak',
#    'title': 'Senior Vice President of Worldwide Marketing',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Adrian  Perica',
#    'age': 50,
#    'title': 'Head of Corporate Development',
#    'yearBorn': 1974,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Michael  Fenger',
#    'title': 'VP of Worldwide Sales',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 3,
#  'boardRisk': 1,
#  'compensationRisk': 3,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 1,
#  'governanceEpochDate': 1735689600,
#  'compensationAsOfEpochDate': 1703980800,
#  'irWebsite': 'http://investor.apple.com/',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 228.26,
#  'open': 232.115,
#  'dayLow': 228.48,
#  'dayHigh': 232.29,
#  'regularMarketPreviousClose': 228.26,
#  'regularMarketOpen': 232.115,
#  'regularMarketDayLow': 228.48,
#  'regularMarketDayHigh': 232.29,
#  'dividendRate': 1.0,
#  'dividendYield': 0.0043,
#  'exDividendDate': 1731024000,
#  'payoutRatio': 0.1612,
#  'fiveYearAvgDividendYield': 0.61,
#  'beta': 1.24,
#  'trailingPE': 37.88797,
#  'forwardPE': 27.693354,
#  'volume': 68488301,
#  'regularMarketVolume': 68488301,
#  'averageVolume': 45900529,
#  'averageVolume10days': 49438970,
#  'averageDailyVolume10Day': 49438970,
#  'bid': 220.21,
#  'ask': 230.16,
#  'bidSize': 100,
#  'askSize': 100,
#  'marketCap': 3458416246784,
#  'fiftyTwoWeekLow': 164.08,
#  'fiftyTwoWeekHigh': 260.1,
#  'priceToSalesTrailing12Months': 8.844263,
#  'fiftyDayAverage': 239.2966,
#  'twoHundredDayAverage': 217.01566,
#  'trailingAnnualDividendRate': 0.98,
#  'trailingAnnualDividendYield': 0.00429335,
#  'currency': 'USD',
#  'enterpriseValue': 3530225090560,
#  'profitMargins': 0.23971,
#  'floatShares': 15091184209,
#  'sharesOutstanding': 15037899776,
#  'sharesShort': 157008120,
#  'sharesShortPriorMonth': 154104746,
#  'sharesShortPreviousMonthDate': 1732838400,
#  'dateShortInterest': 1735603200,
#  'sharesPercentSharesOut': 0.0104,
#  'heldPercentInsiders': 0.02066,
#  'heldPercentInstitutions': 0.62244,
#  'shortRatio': 3.37,
#  'shortPercentOfFloat': 0.0104,
#  'impliedSharesOutstanding': 15671000064,
#  'bookValue': 3.767,
#  'priceToBook': 61.051235,
#  'lastFiscalYearEnd': 1727481600,
#  'nextFiscalYearEnd': 1759017600,
#  'mostRecentQuarter': 1727481600,
#  'earningsQuarterlyGrowth': -0.358,
#  'netIncomeToCommon': 93736001536,
#  'trailingEps': 6.07,
#  'forwardEps': 8.31,
#  'lastSplitFactor': '4:1',
#  'lastSplitDate': 1598832000,
#  'enterpriseToRevenue': 9.028,
#  'enterpriseToEbitda': 26.216,
#  '52WeekChange': 0.18613648,
#  'SandP52WeekChange': 0.23631513,
#  'lastDividendValue': 0.25,
#  'lastDividendDate': 1731024000,
#  'exchange': 'NMS',
#  'quoteType': 'EQUITY',
#  'symbol': 'AAPL',
#  'underlyingSymbol': 'AAPL',
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'firstTradeDateEpochUtc': 345479400,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EST',
#  'uuid': '8b10e4ae-9eeb-3684-921a-9ab27e4d87aa',
#  'messageBoardId': 'finmb_24937',
#  'gmtOffSetMilliseconds': -18000000,
#  'currentPrice': 229.98,
#  'targetHighPrice': 325.0,
#  'targetLowPrice': 184.0,
#  'targetMeanPrice': 247.6305,
#  'targetMedianPrice': 250.0,
#  'recommendationMean': 1.91304,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 41,
#  'totalCash': 65171001344,
#  'totalCashPerShare': 4.311,
#  'ebitda': 134660997120,
#  'totalDebt': 119058997248,
#  'quickRatio': 0.745,
#  'currentRatio': 0.867,
#  'totalRevenue': 391034994688,
#  'debtToEquity': 209.059,
#  'revenuePerShare': 25.485,
#  'returnOnAssets': 0.21464,
#  'returnOnEquity': 1.5741299,
#  'grossProfits': 180682997760,
#  'freeCashflow': 110846001152,
#  'operatingCashflow': 118254002176,
#  'earningsGrowth': -0.341,
#  'revenueGrowth': 0.061,
#  'grossMargins': 0.46206,
#  'ebitdaMargins': 0.34437,
#  'operatingMargins': 0.31171,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 2.0958}

# %%
apple_stock.history().tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-01-13 00:00:00-05:00  233.529999  234.669998  229.720001  234.399994
# 2025-01-14 00:00:00-05:00  234.750000  236.119995  232.470001  233.279999
# 2025-01-15 00:00:00-05:00  234.639999  238.960007  234.429993  237.869995
# 2025-01-16 00:00:00-05:00  237.350006  238.009995  228.029999  228.259995
# 2025-01-17 00:00:00-05:00  232.119995  232.289993  228.479996  229.979996
#
#                              Volume  Dividends  Stock Splits
# Date
# 2025-01-13 00:00:00-05:00  49630700        0.0           0.0
# 2025-01-14 00:00:00-05:00  39435300        0.0           0.0
# 2025-01-15 00:00:00-05:00  39832000        0.0           0.0
# 2025-01-16 00:00:00-05:00  71759100        0.0           0.0
# 2025-01-17 00:00:00-05:00  68247100        0.0           0.0

# %%
apple_stock.get_news()
# Out:
# [{'id': 'f295d9e8-d3fc-46e7-beff-6719c1ad8551',
#   'content': {'id': 'f295d9e8-d3fc-46e7-beff-6719c1ad8551',
#    'contentType': 'STORY',
#    'title': "Stock playbook for Trump's second term: Top sector winners and losers",
#    'description': '',
#    'summary': 'Investors brace for a volatile ride as President-elect Donald Trump’s second term gets underway on Monday, bringing the promise of significant policy shifts.',
#    'pubDate': '2025-01-19T15:30:16Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://s.yimg.com/os/creatr-uploaded-images/2025-01/ac74c710-ce29-11ef-b5bb-e751072d0291',
#     'originalWidth': 5472,
#     'originalHeight': 3600,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/ozm1qHiKXjO4Tqd1_ei1CA--~B/aD0zNjAwO3c9NTQ3MjthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2025-01/ac74c710-ce29-11ef-b5bb-e751072d0291',
#       'width': 5472,
#       'height': 3600,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/9ebrP5MnORWVLK_S7OjeyQ--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2025-01/ac74c710-ce29-11ef-b5bb-e751072d0291',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Yahoo Finance',
#     'url': 'http://finance.yahoo.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/stock-playbook-for-trumps-second-term-top-sector-winners-and-losers-153016808.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/stock-playbook-for-trumps-second-term-top-sector-winners-and-losers-153016808.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': True},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': {'storylineItems': [{'content': {'id': '9830cdb6-1e71-424a-8015-34410a39f9e9',
#        'contentType': 'STORY',
#        'isHosted': True,
#        'title': "TikTok says 'in the process of restoring service' after going dark in US, citing Trump 'clarity'",
#        'thumbnail': {'originalUrl': 'https://s.yimg.com/os/creatr-uploaded-images/2025-01/9424e4b0-d38d-11ef-adff-a753dd8dd315',
#         'originalWidth': 3077,
#         'originalHeight': 2053,
#         'caption': '',
#         'resolutions': None},
#        'provider': {'displayName': 'Yahoo Finance',
#         'sourceId': 'yahoofinance.com'},
#        'previewUrl': None,
#        'providerContentUrl': '',
#        'canonicalUrl': {'url': 'https://finance.yahoo.com/news/tiktok-says-in-the-process-of-restoring-service-after-going-dark-in-us-citing-trump-clarity-050602764.html'},
#        'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/tiktok-says-in-the-process-of-restoring-service-after-going-dark-in-us-citing-trump-clarity-050602764.html'}}},
#      {'content': {'id': '4c760bb8-3b94-3c75-9af7-be1f6609331e',
#        'contentType': 'VIDEO',
#        'isHosted': True,
#        'title': 'After shutting down, TikTok returns following Trump comments',
#        'thumbnail': {'originalUrl': 'https://s.yimg.com/os/creatr-uploaded-images/2025-01/70ff72f0-d51a-11ef-b79e-8f58fa85d2a4',
#         'originalWidth': 6000,
#         'originalHeight': 3378,
#         'caption': '',
#         'resolutions': None},
#        'provider': {'displayName': 'Yahoo Finance Video',
#         'sourceId': 'video.yahoofinance.com'},
#        'previewUrl': None,
#        'providerContentUrl': '',
#        'canonicalUrl': {'url': 'https://finance.yahoo.com/video/tiktok-shuts-down-us-ban-160845836.html'},
#        'clickThroughUrl': {'url': 'https://finance.yahoo.com/video/tiktok-shuts-down-us-ban-160845836.html'}}}]}}},
#  {'id': 'bde3bb23-2390-461e-8a6d-198ac9280409',
#   'content': {'id': 'bde3bb23-2390-461e-8a6d-198ac9280409',
#    'contentType': 'STORY',
#    'title': 'Mag 7, crypto, AI, Trump, tariffs, Fed, and everything else that will dominate Davos',
#    'description': '',
#    'summary': 'Investors would be wise to pay closer attention to the World Economic Forum about to kick off in Davos, Switzerland.',
#    'pubDate': '2025-01-19T13:12:07Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://s.yimg.com/os/creatr-images/2020-01/31769270-3d4a-11ea-bfee-e92a291db2a6',
#     'originalWidth': 5472,
#     'originalHeight': 3620,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/ONyJ3j1cVsGKAgQKKLXhkA--~B/aD0zNjIwO3c9NTQ3MjthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-images/2020-01/31769270-3d4a-11ea-bfee-e92a291db2a6',
#       'width': 5472,
#       'height': 3620,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/JOAXhgYnnT12Os.PyQZKrA--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-images/2020-01/31769270-3d4a-11ea-bfee-e92a291db2a6',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Yahoo Finance',
#     'url': 'http://finance.yahoo.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/mag-7-crypto-ai-trump-tariffs-fed-and-everything-else-that-will-dominate-davos-133033159.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/mag-7-crypto-ai-trump-tariffs-fed-and-everything-else-that-will-dominate-davos-133033159.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': True},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '37463aa3-ca82-38b5-a2ca-c47dd615f411',
#   'content': {'id': '37463aa3-ca82-38b5-a2ca-c47dd615f411',
#    'contentType': 'STORY',
#    'title': 'TikTok is back online after Trump pledged to restore it',
#    'description': '',
#    'summary': 'TikTok appears to be coming back online just hours after President-elect Donald Trump pledged Sunday that he would sign an executive order Monday that aims to restore the banned app.',
#    'pubDate': '2025-01-19T19:09:28Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': None,
#    'provider': {'displayName': 'CNN Business',
#     'url': 'https://www.cnn.com/business'},
#    'canonicalUrl': {'url': 'https://www.cnn.com/2025/01/19/tech/tiktok-ban?cid=external-feeds_iluminar_yahoo',
#     'site': 'news',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://www.yahoo.com/news/tiktok-now-banned-america-might-123057515.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '56df5fc2-f651-33a9-8066-f2d327c85ccb',
#   'content': {'id': '56df5fc2-f651-33a9-8066-f2d327c85ccb',
#    'contentType': 'STORY',
#    'title': 'TikTok Restoring Service After Donald Trump Pledges Reprieve',
#    'description': '',
#    'summary': "TikTok said it's restoring service in the U.S., hours after shutting down, as President-elect Trump said he'll issue an order giving the Chinese-owned site a reprieve.",
#    'pubDate': '2025-01-19T18:09:12Z',
#    'isHosted': False,
#    'bypassModal': False,
#    'previewUrl': 'https://finance.yahoo.com/m/56df5fc2-f651-33a9-8066-f2d327c85ccb/tiktok-restoring-service.html',
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/ibd.com/09b63193397ebd126f34769c054b77cc',
#     'originalWidth': 945,
#     'originalHeight': 533,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Qlvn2Laob6Iee7jUFkungQ--~B/aD01MzM7dz05NDU7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/ibd.com/09b63193397ebd126f34769c054b77cc',
#       'width': 945,
#       'height': 533,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/43_aUdfcYuaMe0wsUrcXbQ--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/ibd.com/09b63193397ebd126f34769c054b77cc',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': "Investor's Business Daily",
#     'url': 'http://www.investors.com/'},
#    'canonicalUrl': {'url': 'https://www.investors.com/news/tiktok-shuts-down-donald-trump-reprieve-likely/?src=A00220&yptr=yahoo',
#     'site': 'news',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': None,
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': 'abbd2f15-9247-3790-b7eb-3faf2cfc6a7c',
#   'content': {'id': 'abbd2f15-9247-3790-b7eb-3faf2cfc6a7c',
#    'contentType': 'STORY',
#    'title': 'Jacquemus Will Use Only iPhones To Capture Fall 2025\xa0Show',
#    'description': '',
#    'summary': "Footage of the brand's Jan. 26 Paris show will tap into the capabilities of the iPhone 16 Pro Max, the latest high-end device from Apple.",
#    'pubDate': '2025-01-19T17:44:06Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/wwd_409/f8089dddb3844063299a3ff8ea207d24',
#     'originalWidth': 1678,
#     'originalHeight': 1272,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/0_1TcKo3PbTOk3D4FSY8sA--~B/aD0xMjcyO3c9MTY3ODthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/wwd_409/f8089dddb3844063299a3ff8ea207d24',
#       'width': 1678,
#       'height': 1272,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/en7KYWg79fMltst0BHoMGA--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/wwd_409/f8089dddb3844063299a3ff8ea207d24',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'WWD', 'url': 'https://wwd.com/'},
#    'canonicalUrl': {'url': 'https://wwd.com/fashion-news/fashion-scoops/jacquemus-show-iphone-paris-fashion-week-1236855856/',
#     'site': 'lifestyle',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://www.yahoo.com/lifestyle/jacquemus-only-iphones-capture-fall-174406262.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '4c39988c-fa5a-3189-ab99-6b45b733dde8',
#   'content': {'id': '4c39988c-fa5a-3189-ab99-6b45b733dde8',
#    'contentType': 'STORY',
#    'title': 'Trump Promises Executive Order Aiding TikTok After App Goes Dark',
#    'description': '',
#    'summary': '(Bloomberg) -- President-elect Donald Trump asked technology companies to “not let TikTok stay dark” and announced he would extend a deadline to sell the company after the video platform suspended its services in the US and Apple Inc. and Google removed the platform from their app stores.Most Read from BloombergNYC Commuters Get New Way to Dodge Traffic: $95 Helicopter RidesScaramucci, Ackman Donate to Whitney Tilson’s NYC Mayoral RunWhat LA’s Fires Mean for the City’s Housing ShortageIn a City',
#    'pubDate': '2025-01-19T15:36:44Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/bloomberg_technology_68/d49b5e953fa5c9e55c0089e2f8186ac1',
#     'originalWidth': 2000,
#     'originalHeight': 1333,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/9yRNdYDctdIdhRIITmDIKQ--~B/aD0xMzMzO3c9MjAwMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/bloomberg_technology_68/d49b5e953fa5c9e55c0089e2f8186ac1',
#       'width': 2000,
#       'height': 1333,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/jnP5GAGZBzH1ufK_jxzb4g--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/bloomberg_technology_68/d49b5e953fa5c9e55c0089e2f8186ac1',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Bloomberg',
#     'url': 'https://www.bloomberg.com/'},
#    'canonicalUrl': {'url': 'https://www.yahoo.com/news/us-tiktok-users-notification-app-023120505.html',
#     'site': 'news',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://www.yahoo.com/news/us-tiktok-users-notification-app-023120505.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '7b739b97-de65-345e-add1-107a22dc02a0',
#   'content': {'id': '7b739b97-de65-345e-add1-107a22dc02a0',
#    'contentType': 'STORY',
#    'title': 'Why Is Apple Inc. (AAPL) Among Louis Navellier’s Top Long-term Stock Picks?',
#    'description': '',
#    'summary': 'We recently compiled a list of the Louis Navellier’s Top 15 Long-Term Stock Picks. In this article, we are going to take a look at where Apple Inc. (NASDAQ:AAPL) stands against the other Louis Navellier’s top long-term stock picks. Louis Navellier is a prominent American investor, author, and financial analyst, best known for his quantitative approach […]',
#    'pubDate': '2025-01-19T12:14:48Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/insidermonkey.com/bd47dc2e86b4a3086f845d200d9daf1f',
#     'originalWidth': 1456,
#     'originalHeight': 816,
#     'caption': 'Apple Inc (AAPL): AI Innovations Shaping the Future',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/fTPNobtT0bdcSxj2xXAamw--~B/aD04MTY7dz0xNDU2O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/bd47dc2e86b4a3086f845d200d9daf1f',
#       'width': 1456,
#       'height': 816,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/ERk7UFMt6k8ofjYa8ja0kw--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/insidermonkey.com/bd47dc2e86b4a3086f845d200d9daf1f',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Insider Monkey',
#     'url': 'http://www.insidermonkey.com'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/why-apple-inc-aapl-among-121448889.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/why-apple-inc-aapl-among-121448889.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '6bdcae05-a12b-35f1-bdeb-94157240cab4',
#   'content': {'id': '6bdcae05-a12b-35f1-bdeb-94157240cab4',
#    'contentType': 'STORY',
#    'title': 'Here\'s How Much You Could Earn in Dividends From a $350,000 Investment in the "Magnificent Seven" Stocks',
#    'description': '',
#    'summary': 'The technology companies nicknamed the "Magnificent Seven" have a combined value of $17.2 trillion, which represents one-third of the entire value of the S&P 500 (SNPINDEX: ^GSPC).  In other words, investors whose portfolios didn\'t include the Magnificent Seven stocks last year probably underperformed the broader market by a wide margin.  Since these seven companies dominate different areas of the technology industry, including new segments like artificial intelligence (AI), they are likely to continue driving the S&P 500 higher.',
#    'pubDate': '2025-01-19T12:13:00Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/motleyfool.com/adfa31a22bf0f89fae81204a712ea6ff',
#     'originalWidth': 720,
#     'originalHeight': 541,
#     'caption': 'NVDA Chart',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/A9b9z0cO1hSdfslS.mroKQ--~B/aD01NDE7dz03MjA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/motleyfool.com/adfa31a22bf0f89fae81204a712ea6ff',
#       'width': 720,
#       'height': 541,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/hlwwk_UzvqOf1FvpkZVjYQ--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/motleyfool.com/adfa31a22bf0f89fae81204a712ea6ff',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Motley Fool', 'url': 'http://www.fool.com/'},
#    'canonicalUrl': {'url': 'https://www.fool.com/investing/2025/01/19/heres-how-dividends-350000-magnificent-seven-stock/?source=eptyholnk0000202&utm_source=yahoo-host-full&utm_medium=feed&utm_campaign=article&referring_guid=29ab9a98-2e3d-4d7a-bde8-de5807a8bb48',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/heres-much-could-earn-dividends-121300613.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '7a23bd4b-01c3-31e6-ac96-e500fd30e1fc',
#   'content': {'id': '7a23bd4b-01c3-31e6-ac96-e500fd30e1fc',
#    'contentType': 'STORY',
#    'title': 'With 61% ownership of the shares, Apple Inc. (NASDAQ:AAPL) is heavily dominated by institutional owners',
#    'description': '',
#    'summary': "Key Insights Given the large stake in the stock by institutions, Apple's stock price might be vulnerable to their...",
#    'pubDate': '2025-01-19T11:00:32Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/simply_wall_st__316/13f69b02f49f819df1dcc276114d4a99',
#     'originalWidth': 1194,
#     'originalHeight': 432,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/.m1ghW2JIKMrn_021vRckQ--~B/aD00MzI7dz0xMTk0O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/simply_wall_st__316/13f69b02f49f819df1dcc276114d4a99',
#       'width': 1194,
#       'height': 432,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/v2JXrvDC2SwXU9VOf.KlrA--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/simply_wall_st__316/13f69b02f49f819df1dcc276114d4a99',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Simply Wall St.',
#     'url': 'https://simplywall.st/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/61-ownership-shares-apple-inc-110032059.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/61-ownership-shares-apple-inc-110032059.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '40f5ba0d-8904-3188-adbc-61d3c9d7523d',
#   'content': {'id': '40f5ba0d-8904-3188-adbc-61d3c9d7523d',
#    'contentType': 'STORY',
#    'title': "Warren Buffett Owns 6 Dow Jones Stocks. Here's the Best of the Bunch for Income Investors to Buy Right Now.",
#    'description': '',
#    'summary': "Warren Buffett primarily buys large-cap stocks for Berkshire Hathaway's portfolio.  Because of this focus on large-cap stocks, you probably won't be surprised that Buffett owns six stocks that are members of the Dow Jones Industrial Average (DJINDICES: ^DJI).  The two stocks Buffett has owned the longest are both members of the Dow.",
#    'pubDate': '2025-01-19T09:20:00Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/motleyfool.com/5f4a7e04922468335fee8bc81dabc43e',
#     'originalWidth': 2048,
#     'originalHeight': 1365,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/2AP_ICY_o.R_PNWbgyMSww--~B/aD0xMzY1O3c9MjA0ODthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/motleyfool.com/5f4a7e04922468335fee8bc81dabc43e',
#       'width': 2048,
#       'height': 1365,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/ZTlK0iRjzIJf2YEJDEN.bg--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/motleyfool.com/5f4a7e04922468335fee8bc81dabc43e',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Motley Fool', 'url': 'http://www.fool.com/'},
#    'canonicalUrl': {'url': 'https://www.fool.com/investing/2025/01/19/warren-buffett-owns-6-dow-jones-stocks-heres-the-b/?source=eptyholnk0000202&utm_source=yahoo-host-full&utm_medium=feed&utm_campaign=article&referring_guid=5840d970-672e-4994-a426-25b42d553a42',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/warren-buffett-owns-6-dow-092000207.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}}]

# %%
apple_stock.history(period="1mo", interval="5m")
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2024-12-16 09:30:00-05:00  248.000000  249.990005  247.649994  249.926605
# 2024-12-16 09:35:00-05:00  249.919998  249.970001  249.479996  249.710007
# 2024-12-16 09:40:00-05:00  249.699997  250.000000  249.460007  249.699997
# 2024-12-16 09:45:00-05:00  249.710007  249.789993  248.850006  248.970001
# 2024-12-16 09:50:00-05:00  248.979996  249.100006  248.600006  249.100006
# ...                               ...         ...         ...         ...
# 2025-01-14 15:35:00-05:00  232.929993  233.190002  232.720001  232.720001
# 2025-01-14 15:40:00-05:00  232.720093  232.979996  232.539993  232.979996
# 2025-01-14 15:45:00-05:00  232.979996  233.100006  232.928406  232.960007
# 2025-01-14 15:50:00-05:00  232.979996  233.440002  232.925003  233.289993
# 2025-01-14 15:55:00-05:00  233.279999  233.399994  232.779999  233.279999
#
#                             Volume  Dividends  Stock Splits
# Datetime
# 2024-12-16 09:30:00-05:00  2747902        0.0           0.0
# 2024-12-16 09:35:00-05:00   577478        0.0           0.0
# 2024-12-16 09:40:00-05:00   453003        0.0           0.0
# 2024-12-16 09:45:00-05:00   414881        0.0           0.0
# 2024-12-16 09:50:00-05:00   395577        0.0           0.0
# ...                            ...        ...           ...
# 2025-01-14 15:35:00-05:00   310132        0.0           0.0
# 2025-01-14 15:40:00-05:00   418887        0.0           0.0
# 2025-01-14 15:45:00-05:00   431513        0.0           0.0
# 2025-01-14 15:50:00-05:00  1095905        0.0           0.0
# 2025-01-14 15:55:00-05:00  2301939        0.0           0.0
#
# [1446 rows x 7 columns]

# %%
apple_stock.history(period="5d", interval="1m")
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2025-01-07 09:30:00-05:00  242.979996  243.970001  242.830002  243.395004
# 2025-01-07 09:31:00-05:00  243.429993  243.789993  243.380005  243.630005
# 2025-01-07 09:32:00-05:00  243.630005  244.279297  243.610001  244.179993
# 2025-01-07 09:33:00-05:00  244.184998  244.929993  244.184998  244.440002
# 2025-01-07 09:34:00-05:00  244.440002  244.470001  243.910004  243.940002
# ...                               ...         ...         ...         ...
# 2025-01-14 15:55:00-05:00  233.270004  233.279999  232.782196  232.839996
# 2025-01-14 15:56:00-05:00  232.830002  233.029999  232.779999  233.014999
# 2025-01-14 15:57:00-05:00  233.014999  233.300003  232.994995  233.250000
# 2025-01-14 15:58:00-05:00  233.259995  233.259995  232.979996  233.009995
# 2025-01-14 15:59:00-05:00  233.000000  233.399994  233.000000  233.279999
#
#                             Volume  Dividends  Stock Splits
# Datetime
# 2025-01-07 09:30:00-05:00  1932711        0.0           0.0
# 2025-01-07 09:31:00-05:00   151668        0.0           0.0
# 2025-01-07 09:32:00-05:00   190205        0.0           0.0
# 2025-01-07 09:33:00-05:00   272093        0.0           0.0
# 2025-01-07 09:34:00-05:00   159076        0.0           0.0
# ...                            ...        ...           ...
# 2025-01-14 15:55:00-05:00   204914        0.0           0.0
# 2025-01-14 15:56:00-05:00   181282        0.0           0.0
# 2025-01-14 15:57:00-05:00   226389        0.0           0.0
# 2025-01-14 15:58:00-05:00   191382        0.0           0.0
# 2025-01-14 15:59:00-05:00   661321        0.0           0.0
#
# [1950 rows x 7 columns]

# %%
apple_stock.history(start="2024-01-01", end="2024-12-31")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-01-02 00:00:00-05:00  186.237618  187.521338  182.993517  184.734985
# 2024-01-03 00:00:00-05:00  183.321908  184.973819  182.535751  183.351761
# 2024-01-04 00:00:00-05:00  181.261983  182.197403  179.998185  181.023163
# 2024-01-05 00:00:00-05:00  181.102771  181.869006  179.291637  180.296707
# 2024-01-08 00:00:00-05:00  181.202281  184.695178  180.615161  184.655365
# ...                               ...         ...         ...         ...
# 2024-12-23 00:00:00-05:00  254.770004  255.649994  253.449997  255.270004
# 2024-12-24 00:00:00-05:00  255.490005  258.209991  255.289993  258.200012
# 2024-12-26 00:00:00-05:00  258.190002  260.100006  257.630005  259.019989
# 2024-12-27 00:00:00-05:00  257.829987  258.700012  253.059998  255.589996
# 2024-12-30 00:00:00-05:00  252.229996  253.500000  250.750000  252.199997
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-01-02 00:00:00-05:00  82488700        0.0           0.0
# 2024-01-03 00:00:00-05:00  58414500        0.0           0.0
# 2024-01-04 00:00:00-05:00  71983600        0.0           0.0
# 2024-01-05 00:00:00-05:00  62303300        0.0           0.0
# 2024-01-08 00:00:00-05:00  59144500        0.0           0.0
# ...                             ...        ...           ...
# 2024-12-23 00:00:00-05:00  40858800        0.0           0.0
# 2024-12-24 00:00:00-05:00  23234700        0.0           0.0
# 2024-12-26 00:00:00-05:00  27237100        0.0           0.0
# 2024-12-27 00:00:00-05:00  42355300        0.0           0.0
# 2024-12-30 00:00:00-05:00  35557500        0.0           0.0
#
# [251 rows x 7 columns]

# %%
df = yf.Tickers("AAPL AMZN MSFT TSLA").history(period="5d")
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
empresas = df['Close'].columns
empresas
# Out:
# Index(['AAPL', 'AMZN', 'MSFT', 'TSLA'], dtype='object', name='Ticker')

# %%
df.sort_index()
# Out:
# Price            Close                                     Dividends       \
# Ticker            AAPL        AMZN        MSFT        TSLA      AAPL AMZN
# Date
# 2025-01-13  234.399994  218.460007  417.190002  403.309998       0.0  0.0
# 2025-01-14  233.279999  217.759995  415.670013  396.359985       0.0  0.0
# 2025-01-15  237.869995  223.350006  426.309998  428.220001       0.0  0.0
# 2025-01-16  228.259995  220.660004  424.579987  413.820007       0.0  0.0
# 2025-01-17  229.979996  225.940002  429.029999  426.500000       0.0  0.0
#
# Price                       High              ...        Open              \
# Ticker     MSFT TSLA        AAPL        AMZN  ...        MSFT        TSLA
# Date                                          ...
# 2025-01-13  0.0  0.0  234.669998  219.399994  ...  415.239990  383.209991
# 2025-01-14  0.0  0.0  236.119995  221.820007  ...  417.809998  414.339996
# 2025-01-15  0.0  0.0  238.960007  223.570007  ...  419.130005  409.899994
# 2025-01-16  0.0  0.0  238.009995  224.649994  ...  428.700012  423.489990
# 2025-01-17  0.0  0.0  232.289993  226.509995  ...  434.089996  421.500000
#
# Price      Stock Splits                   Volume
# Ticker             AAPL AMZN MSFT TSLA      AAPL      AMZN      MSFT      TSLA
# Date
# 2025-01-13          0.0  0.0  0.0  0.0  49630700  27262700  17604800  67580500
# 2025-01-14          0.0  0.0  0.0  0.0  39435300  24711700  16935900  84565000
# 2025-01-15          0.0  0.0  0.0  0.0  39832000  31291300  19637800  81375500
# 2025-01-16          0.0  0.0  0.0  0.0  71759100  24757300  15300000  68335200
# 2025-01-17          0.0  0.0  0.0  0.0  68247100  42108900  26148000  94504200
#
# [5 rows x 28 columns]
